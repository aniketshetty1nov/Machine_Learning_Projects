# %%
# My Fake News Detection Project 
# Importing All the Required Libraries
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report # accurcy score to calculate the accuracy of our model

import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier 
import string

# %%
my_true_news = pd.read_csv('DATASETS/True.csv')

# %%
my_fake_news = pd.read_csv('DATASETS/Fake.csv')
# Out:
# 'House Intelligence Committee Chairman Devin Nunes is going to have a bad day. He s been under the assumption, like many of us, that the Christopher Steele-dossier was what prompted the Russia investigation so he s been lashing out at the Department of Justice and the FBI in order to protect Trump. As it happens, the dossier is not what started the investigation, according to documents obtained by the New York Times.Former Trump campaign adviser George Papadopoulos was drunk in a wine bar when he revealed knowledge of Russian opposition research on Hillary Clinton.On top of that, Papadopoulos wasn t just a covfefe boy for Trump, as his administration has alleged. He had a much larger role, but none so damning as being a drunken fool in a wine bar. Coffee boys  don t help to arrange a New York meeting between Trump and President Abdel Fattah el-Sisi of Egypt two months before the election. It was known before that the former aide set up meetings with world leaders for Trump, but team 
# ...

# %%
my_fake_news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
my_true_news.head()
my_true_news['text'][9]
# Out:
# 'WASHINGTON (Reuters) - Alabama Secretary of State John Merrill said he will certify Democratic Senator-elect Doug Jones as winner on Thursday despite opponent Roy Moore’s challenge, in a phone call on CNN. Moore, a conservative who had faced allegations of groping teenage girls when he was in his 30s, filed a court challenge late on Wednesday to the outcome of a U.S. Senate election he unexpectedly lost. '

# %% [markdown]
# # True News -1 Fake News - 0

# %%
my_true_news['label'] = 1  # Inserting a New Column as Label to classify as True News or False News
my_fake_news['label'] = 0

# %%
my_true_news.shape, my_fake_news.shape
# Out:
# ((21417, 5), (23481, 5))

# %%
# Removing last 10 rows for manual testing
df_fake_manual_testing = my_fake_news.tail(10)
for i in range(23480,23470,-1):
    my_fake_news.drop([i], axis = 0, inplace = True)
    
    
df_true_manual_testing = my_true_news.tail(10)
for i in range(21416,21406,-1):
    my_true_news.drop([i], axis = 0, inplace = True)

# %% [markdown]
# ### Merging the two dataframes True and False Dataframes

# %%
my_true_news.shape, my_fake_news.shape
# Out:
# ((21407, 5), (23471, 5))

# %%
theNews = pd.concat([my_fake_news,my_true_news],axis=0)
theNews.shape
# Out:
# (44878, 5)

# %%
df_manual_testing = pd.concat([df_fake_manual_testing,df_true_manual_testing], axis = 0)
df_manual_testing.to_csv("manual_testing.csv")

# %%
theNews.head()

# Binary – ‘label’
# Nominal – ’subject’
# Ordinal - None
# Numerical – ‘date'
# Textual – ‘title’, ‘text’

# theNews['text'][1]
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
theNews.tail()
# Out:
#                                                    title  \
# 21402  Exclusive: Trump's Afghan decision may increas...
# 21403  U.S. puts more pressure on Pakistan to help wi...
# 21404  Exclusive: U.S. to withhold up to $290 million...
# 21405  Trump talks tough on Pakistan's 'terrorist' ha...
# 21406  U.S., North Korea clash at U.N. forum over nuc...
#
#                                                     text    subject  \
# 21402  ON BOARD A U.S. MILITARY AIRCRAFT (Reuters) - ...  worldnews
# 21403  WASHINGTON (Reuters) - The United States sugge...  worldnews
# 21404  WASHINGTON (Reuters) - The United States has d...  worldnews
# 21405  ISLAMABAD (Reuters) - Outlining a new strategy...  worldnews
# 21406  GENEVA (Reuters) - North Korea and the United ...  worldnews
#
#                    date  label
# 21402  August 22, 2017       1
# 21403  August 21, 2017       1
# 21404  August 22, 2017       1
# 21405  August 22, 2017       1
# 21406  August 22, 2017       1

# %%
theNews.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
theNews.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
#Check whether we have duplicates
theNews.duplicated().sum()
# Out:
# 208

# %%
theNews[theNews.duplicated()].head()
# Out:
#                                                    title  \
# 9942   HILLARY TWEETS MESSAGE In Defense Of DACA…OOPS...
# 11446  FORMER DEMOCRAT WARNS Young Americans: “Rioter...
# 14925  [VIDEO] #BlackLivesMatter Terrorists Storm Dar...
# 445    Senate tax bill stalls on deficit-focused 'tri...
# 778    Trump warns 'rogue regime' North Korea of grav...
#
#                                                     text       subject  \
# 9942   No time to waste   we've got to fight with eve...      politics
# 11446   Who is silencing political speech, physically...      politics
# 14925  They were probably just looking for a  safe sp...      politics
# 445    WASHINGTON (Reuters) - The U.S. Senate on Thur...  politicsNews
# 778    BEIJING (Reuters) - U.S. President Donald Trum...  politicsNews
#
#                      date  label
# 9942          Sep 9, 2017      0
# 11446        Mar 10, 2017      0
# 14925        Nov 16, 2015      0
# 445    November 30, 2017       1
# ...

# %%
# we can drop the duplcates
# lets drop duplicates and save resulting dataframe
theNews = theNews.drop_duplicates(keep='first')

# Display first few rows of new dataframe as needed
theNews.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %% [markdown]
# ## Now we will Do Feature Selection

# %%
#Removing Columns which are not required
theNews= theNews.drop(['title','subject','date'],axis=1)

# %%
theNews.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
# As the Top part of or sample datasets are fake news and bottom part is True News so it might create our model biased.
# so that we will use below code to avoid that and do a Random shuffling of the dataframe
theNews = theNews.sample(frac=1)  #Reshuffling

# %%
theNews.head()
# Out:
#                                                     text  label
# 20607  (Reuters) - Florida s insurance and reinsuranc...      1
# 3533   TAORMINA, Italy (Reuters) - Asked about report...      1
# 7503   WASHINGTON (Reuters) - Democratic Party offici...      1
# 15843  Since Hillary s making a big announcement toda...      0
# 4882   WASHINGTON (Reuters) - President Donald Trump ...      1

# %%
theNews.reset_index(inplace=True)

# %%
theNews.head()
# Out:
#    index                                               text  label
# 0  20607  (Reuters) - Florida s insurance and reinsuranc...      1
# 1   3533  TAORMINA, Italy (Reuters) - Asked about report...      1
# 2   7503  WASHINGTON (Reuters) - Democratic Party offici...      1
# 3  15843  Since Hillary s making a big announcement toda...      0
# 4   4882  WASHINGTON (Reuters) - President Donald Trump ...      1

# %%
theNews.drop(['index'], axis=1, inplace=True)

# %%
theNews.head(10)
# Out:
#                                                 text  label
# 0  (Reuters) - Florida s insurance and reinsuranc...      1
# 1  TAORMINA, Italy (Reuters) - Asked about report...      1
# 2  WASHINGTON (Reuters) - Democratic Party offici...      1
# 3  Since Hillary s making a big announcement toda...      0
# 4  WASHINGTON (Reuters) - President Donald Trump ...      1
# 5  GENERAL MCINERNEY IS ON FIRE IN THIS INTERVIEW...      0
# 6  On the National Day of Prayer, Donald Trump la...      0
# 7  BAGHDAD (Reuters) - Kurdish officials said on ...      1
# 8  What do you think of these comments made by Do...      0
# 9  Donald Trump keeps pretending that everyone is...      0

# %%
theNews.describe() #summary of the data
# Out:
#               label
# count  44670.000000
# mean       0.474636
# std        0.499362
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count the frequency of each value (0 and 1) in the 'Value' column
decision_counts = theNews['label'].value_counts()
plt.figure(figsize=(8, 6))  # Set the figure size (width, height)
# Lets now create a bar plot
decision_counts.plot(kind='bar', color=['skyblue', 'orange'])

# Labeling everything
plt.xlabel('True-1 vs Fake-0')  # Label for x-axis
plt.ylabel('Frequency')  # Label for y-axis
plt.title('Frequency of Fake News and True News') # title of our chart

# Display the plot
plt.xticks(rotation=0)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import re

# %% [markdown]
# ### Feature Extraction

# %%
def wordopt(text):
    # convert into lowercase 
    text = text.lower()
    
    # Remove URls 
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    
    # Remove HTML Tags
    text = re.sub(r'<.*?>','',text)
    
    # Remove Punctuation
    text = re.sub(r'[^\w\s]','',text)
    
    # Remove Digits
    text = re.sub(r'\d','',text)
    
    #Remove Newline Characters
    text = re.sub(r'\n', ' ', text)
    
    #match and remove text enclosed within square brackets, including the square brackets themselves, 
    text = re.sub('\[.*?\]', '', text)
    
    #replace all non-alphanumeric characters in the text with space characters
    text = re.sub("\\W"," ",text) 
    
        
    # to remove any alphanumeric strings containing at least one digit from the text
    text = re.sub('\w*\d\w*', '', text)    
    
    return text

# %%
theNews['text'] = theNews['text'].apply(wordopt)
theNews['text']
theNews.head(10)
# Out:
#                                                 text  label
# 0  reuters  florida s insurance and reinsurance m...      1
# 1  taormina italy reuters  asked about reports th...      1
# 2  washington reuters  democratic party officials...      1
# 3  since hillary s making a big announcement toda...      0
# 4  washington reuters  president donald trump mai...      1
# 5  general mcinerney is on fire in this interview...      0
# 6  on the national day of prayer donald trump las...      0
# 7  baghdad reuters  kurdish officials said on thu...      1
# 8  what do you think of these comments made by do...      0
# 9  donald trump keeps pretending that everyone is...      0

# %% [markdown]
# ### Defining dependent and independent variables

# %%
x = theNews['text']
y = theNews['label']

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 44665    0
# 44666    0
# 44667    0
# 44668    0
# 44669    0
# Name: label, Length: 44670, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31269,)

# %%
x_test.shape
# Out:
# (13401,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Convert text to vectors

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31269x174415 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6403067 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13401x174415 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2721519 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Using Sklearn package to Implement  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9875382434146706

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7077
#            1       0.98      0.99      0.99      6324
#
#     accuracy                           0.99     13401
#    macro avg       0.99      0.99      0.99     13401
# weighted avg       0.99      0.99      0.99     13401

# %%
# Defining New Dict variables to store all out accuracy & F1 scores.
Accuracies = {}
F1Scores = {}

Accuracies['sklearn_Logis']= accuracy_score(y_test, pred_lr)
F1Scores['sklearn_Logis']= f1_score(y_test, pred_lr)
Accuracies
F1Scores
print(f"The accuracy score on our test data of our logistic using skLearn model is: {Accuracies['sklearn_Logis']}")
print(f"The F1 score on our test data of our logistic using skLearn model is: {F1Scores['sklearn_Logis']}")
# Out:
# The accuracy score on our test data of our logistic using skLearn model is: 0.9875382434146706
# The F1 score on our test data of our logistic using skLearn model is: 0.9868472867606521

# %%
# Compute confusion matrix
def PlotConusionMatrix(y_test, pred):
    cnfsnMatrx = confusion_matrix(y_test, pred)

    # Lets plot the confusion matrix 
    plt.figure(figsize=(5, 4))
    sns.heatmap(cnfsnMatrx, annot=True, fmt='d', cmap='gist_ncar_r', cbar=False,annot_kws={"fontsize": 14})
    plt.xlabel('Predicted labels',fontsize=14)
    plt.ylabel('True labels',fontsize=14)
    plt.title('Confusion Matrix for SKlearn Logistic Regression',fontsize=16)

    plt.show()

PlotConusionMatrix(y_test,pred_lr)

# %%
# The Model predicted 6376 (True Positives) i.e 6376 true news and missed out 61
# and 6968 Fake news were predeicted by the model but it missed 6948 of them

# %% [markdown]
# # Using Xboost Package to implement Logistic Regression Algorithm
# https://forecastegy.com/posts/xgboost-binary-classification-python/

# %%
from xgboost import XGBClassifier

# Create an instance of the XGBClassifier
XGB_LogisModel = XGBClassifier(objective='binary:logistic')

# Fit the model to the training data
XGB_LogisModel.fit(xv_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### Making Predictions

# %%
# Make class predictions
y_XGB_Logis_pred = XGB_LogisModel.predict(xv_test)
y_XGB_Logis_pred                       
# In this case, every instance with a probability greater than 0.5 will be classified as ‘good’ (1) and the rest as ’not good’ (0).
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
# Predicting Probabilities
# Most of the time, we want to know the probabilities that an instance belongs to each class, so we can use a different threshold if we want or use the probabilities directly downstream.

# Let’s say we are predicting if a stock will go up or down.

# A portfolio manager might plug these predictions into an expected value formula to decide whether to buy or sell the stock.

# The predict_proba() function returns the probabilities for each class.
y_XGB_Logis_pred_proba = XGB_LogisModel.predict_proba(xv_test)
y_XGB_Logis_pred_proba
# Out:
# array([[9.9996752e-01, 3.2485310e-05],
#        [9.9998927e-01, 1.0744110e-05],
#        [4.2492151e-04, 9.9957508e-01],
#        ...,
#        [8.1062317e-06, 9.9999189e-01],
#        [3.3140182e-05, 9.9996686e-01],
#        [1.7642975e-05, 9.9998236e-01]], dtype=float32)

# %%
# The left column is the probability that the instance belongs to the negative class (0) and the right column is the probability that it belongs to the positive class (1).

# %% [markdown]
# ### Evaluating Model Performance

# %%
# Evaluating the performance of a model is a crucial step in machine learning.
# It helps us understand how well our model is doing and where it can be improved.
# Let’s look at some of the ways we can do it.

# %%
# Calculate accuracy
accuracy = XGB_LogisModel.score(xv_test, y_test)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 99.75%

# %%
# assigning the score to the dict
Accuracies['XGB_Logis']= accuracy_score(y_test, y_XGB_Logis_pred)
F1Scores['XGB_Logis']= f1_score(y_test, y_XGB_Logis_pred)

print(f"The accuracy score on our test data of our logistic using XGboost model is: {Accuracies['XGB_Logis']} ")
print(f"The F1 score on our test data of our logistic using XGboost model is: {F1Scores['XGB_Logis']} ")
# Out:
# The accuracy score on our test data of our logistic using XGboost model is: 0.9974628759047832
# The F1 score on our test data of our logistic using XGboost model is: 0.9973148001895435

# %%
from sklearn.metrics import log_loss, roc_auc_score

# Calculate log loss
log_loss(y_test, y_XGB_Logis_pred_proba)

# Calculate ROC AUC
roc_auc_score(y_test, y_XGB_Logis_pred_proba[:,1])
# Out:
# 0.9998762930078704

# %%
from sklearn.metrics import classification_report

# Print classification report
print(classification_report(y_test, y_XGB_Logis_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7077
#            1       1.00      1.00      1.00      6324
#
#     accuracy                           1.00     13401
#    macro avg       1.00      1.00      1.00     13401
# weighted avg       1.00      1.00      1.00     13401

# %%
# Compute confusion matrix
def PlotConusionMatrix(y_test, pred):
    cnfsnMatrx = confusion_matrix(y_test, pred)

    # Lets plot the confusion matrix 
    plt.figure(figsize=(5, 4))
    sns.heatmap(cnfsnMatrx, annot=True, fmt='d', cmap='gist_ncar_r', cbar=False,annot_kws={"fontsize": 14})
    plt.xlabel('Predicted labels',fontsize=14)
    plt.ylabel('True labels',fontsize=14)
    plt.title('Confusion Matrix for XGBoost Logistic Regression',fontsize=16)

    plt.show()

PlotConusionMatrix(y_test,y_XGB_Logis_pred)

# %% [markdown]
# # Decision Tree using Sklearn

# %%
DTC = DecisionTreeClassifier()  # Defining the model
DTC.fit(xv_train,y_train) # Fitting the model of decision tree
# Out:
# DecisionTreeClassifier()

# %%
pred_dtcSK = DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)
# Out:
# 0.995746586075666

# %%
# our classification measures
print(classification_report(y_test,pred_dtcSK))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7077
#            1       0.99      1.00      1.00      6324
#
#     accuracy                           1.00     13401
#    macro avg       1.00      1.00      1.00     13401
# weighted avg       1.00      1.00      1.00     13401

# %%
# assigning the score to the dict
Accuracies['SKLearn_DecTree']= accuracy_score(y_test, pred_dtcSK)
F1Scores['SKLearn_DecTree']= f1_score(y_test, pred_dtcSK)


print(f"The accuracy score on our test data of our Decision Tree using Sklearn model is: {Accuracies['SKLearn_DecTree']} ")
print(f"The F1 score on our test data of our Decision Tree using Sklearn model is: {F1Scores['SKLearn_DecTree']} ")
# Out:
# The accuracy score on our test data of our Decision Tree using Sklearn model is: 0.995746586075666
# The F1 score on our test data of our Decision Tree using Sklearn model is: 0.9955001184179364

# %%
# Compute confusion matrix
def PlotConusionMatrix(y_test, pred):
    cnfsnMatrx = confusion_matrix(y_test, pred)

    # Lets plot the confusion matrix 
    plt.figure(figsize=(5, 4))
    sns.heatmap(cnfsnMatrx, annot=True, fmt='d', cmap='gist_ncar_r', cbar=False,annot_kws={"fontsize": 14})
    plt.xlabel('Predicted labels',fontsize=14)
    plt.ylabel('True labels',fontsize=14)
    plt.title('Confusion Matrix for SKLearn Decision Tree',fontsize=16)

    plt.show()

PlotConusionMatrix(y_test,pred_dtcSK)

# %% [markdown]
# ## Using Xboost Creating a decision Tree Algorithm

# %%
xgbDecision3Model = xgb.XGBClassifier()  # Defining the model
# Training and fitting the model
xgbDecision3Model.fit(xv_train, y_train)
# Make predictions
xgbDecpredictions = xgbDecision3Model.predict(xv_test)

# %%
xgbDecision3Model.score(xv_test,y_test)
# Out:
# 0.9974628759047832

# %%
print(classification_report(y_test,xgbDecpredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7077
#            1       1.00      1.00      1.00      6324
#
#     accuracy                           1.00     13401
#    macro avg       1.00      1.00      1.00     13401
# weighted avg       1.00      1.00      1.00     13401

# %%
# Compute confusion matrix
def PlotConusionMatrix(y_test, pred):
    cnfsnMatrx = confusion_matrix(y_test, pred)

    # Lets plot the confusion matrix 
    plt.figure(figsize=(5, 4))
    sns.heatmap(cnfsnMatrx, annot=True, fmt='d', cmap='gist_ncar_r', cbar=False,annot_kws={"fontsize": 14})
    plt.xlabel('Predicted labels',fontsize=14)
    plt.ylabel('True labels',fontsize=14)
    plt.title('Confusion Matrix for XGBoost Decision Tree',fontsize=16)

    plt.show()

PlotConusionMatrix(y_test,xgbDecpredictions)

# %%
# assigning the score to the dict
Accuracies['XGB_DecTree']= accuracy_score(y_test, xgbDecpredictions)
F1Scores['XGB_DecTree']= f1_score(y_test, xgbDecpredictions)


print(f"The accuracy score on our test data of our Decision Tree using XGboost model is: {Accuracies['XGB_DecTree']}")
print(f"The F1 score on our test data of our Decision Tree using XGboost model is: {F1Scores['XGB_DecTree']}")
# Out:
# The accuracy score on our test data of our Decision Tree using XGboost model is: 0.9974628759047832
# The F1 score on our test data of our Decision Tree using XGboost model is: 0.9973148001895435

# %%
# Comparing Scores of all the Model.

# %%
print("Model Accuracies:")
for mname, accuracy in Accuracies.items():
    print(f"{mname}: {accuracy:.4f}")
# Out:
# Model Accuracies:
# sklearn_Logis: 0.9875
# XGB_Logis: 0.9975
# SKLearn_DecTree: 0.9957
# XGB_DecTree: 0.9975

# %%
print("Model Accuracies:")
for mname, accuracy in Accuracies.items():
    print(f"{mname}: {accuracy:.4f}")
# Out:
# Model Accuracies:
# sklearn_Logis: 0.9875
# XGB_Logis: 0.9975
# SKLearn_DecTree: 0.9957
# XGB_DecTree: 0.9975

# %%
# Below are model names and accuracy scores
TwiAnmodelNames = list(Accuracies.keys())   # getting the key's from dict
TwiAnaccuracyScores = list(Accuracies.values())  # getting the values's from dict

# Plot a bar graph to visulise the accuracy scores
plt.figure(figsize=(15, 7))
plt.bar(TwiAnmodelNames, TwiAnaccuracyScores, color='skyblue')
plt.xlabel('All Models & Libraries', fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.title('Accuracy of Different Models & Libraries', fontsize=20)
# plt.ylim(0.92, 1)  # Set y-axis limits to better visualize differences
plt.xticks(rotation=0, fontsize=17) 
plt.yticks(rotation=0, fontsize=17)
plt.show()

# %%
# Below are model names and accuracy scores
TwiAnmodelNames = list(F1Scores.keys())
TwiAnF1Scores = list(F1Scores.values())


# Plot a bar graph to visulise the accuracy scores
plt.figure(figsize=(15, 7))
plt.bar(TwiAnmodelNames, TwiAnF1Scores, color='gold')
plt.xlabel('All Models & Libraries', fontsize=18)
plt.ylabel('F1 Scores', fontsize=18)
plt.title('F1 Scores of Different Models & Libraries', fontsize=20)
# plt.ylim(0.92, 1)  # Set y-axis limits to better visualize differences
plt.xticks(rotation=0, fontsize=17) 
plt.yticks(rotation=0, fontsize=17)
plt.show()

# %% [markdown]
# #### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBC = GradientBoostingClassifier(random_state=0)
GBC.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gbc = GBC.predict(xv_test)

# %%
GBC.score(xv_test, y_test)
# Out:
# 0.9956719647787479

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7077
#            1       0.99      1.00      1.00      6324
#
#     accuracy                           1.00     13401
#    macro avg       1.00      1.00      1.00     13401
# weighted avg       1.00      1.00      1.00     13401

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(random_state=0)
RFC.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rfc = RFC.predict(xv_test)

# %%
RFC.score(xv_test, y_test)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# 0.988806805462279

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7077
#            1       0.98      0.99      0.99      6324
#
#     accuracy                           0.99     13401
#    macro avg       0.99      0.99      0.99     13401
# weighted avg       0.99      0.99      0.99     13401

# %% [markdown]
# ### Model Testing

# %%
def output_lable(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt) 
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DTC.predict(new_xv_test)
#     pred_GBC = GBC.predict(new_xv_test)
#     pred_RFC = RFC.predict(new_xv_test)

#     return print("\n\nLR Prediction: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(output_lable(pred_LR[0]),                                                                                                       
#                                                                                                               output_lable(pred_DT[0])
#                                                                                                               output_lable(pred_GBC[0]), 
#                                                                                                               output_lable(pred_RFC[0])
#                                                                                                              ))

    return print("\n\nLR Prediction: {} \nDT Prediction: {}".format(output_lable(pred_LR[0]),                                                                                                       
                                                                    output_lable(pred_DT[0])
                                                                    ))

# %%
news = str(input())
manual_testing(news)
# Out:
# Vic Bishop Waking TimesOur reality is carefully constructed by powerful corporate, political and special interest sources in order to covertly sway public opinion. Blatant lies are often televised regarding terrorism, food, war, health, etc. They are fashioned to sway public opinion and condition viewers to accept what have become destructive societal norms.The practice of manipulating and controlling public opinion with distorted media messages has become so common that there is a whole industry formed around this. The entire role of this brainwashing industry is to figure out how to spin information to journalists, similar to the lobbying of government. It is never really clear just how much truth the journalists receive because the news industry has become complacent. The messages that it presents are shaped by corporate powers who often spend millions on advertising with the six conglomerates that own 90% of the media:General Electric (GE), News-Corp, Disney, Viacom, Time Warner,
# ...

# %%
# Vic Bishop Waking TimesOur reality is carefully constructed by powerful corporate, political and special interest sources in order to covertly sway public opinion. Blatant lies are often televised regarding terrorism, food, war, health, etc. They are fashioned to sway public opinion and condition viewers to accept what have become destructive societal norms.The practice of manipulating and controlling public opinion with distorted media messages has become so common that there is a whole industry formed around this. The entire role of this brainwashing industry is to figure out how to spin information to journalists, similar to the lobbying of government. It is never really clear just how much truth the journalists receive because the news industry has become complacent. The messages that it presents are shaped by corporate powers who often spend millions on advertising with the six conglomerates that own 90% of the media:General Electric (GE), News-Corp, Disney, Viacom, Time Warner, and CBS. Yet, these corporations function under many different brands, such as FOX, ABC, CNN, Comcast, Wall Street Journal, etc, giving people the perception of choice   As Tavistock s researchers showed, it was important that the victims of mass brainwashing not be aware that their environment was being controlled; there should thus be a vast number of sources for information, whose messages could be varied slightly, so as to mask the sense of external control. ~ Specialist of mass brainwashing, L. WolfeNew Brainwashing Tactic Called AstroturfWith alternative media on the rise, the propaganda machine continues to expand. Below is a video of Sharyl Attkisson, investigative reporter with CBS, during which she explains how  astroturf,  or fake grassroots movements, are used to spin information not only to influence journalists but to sway public opinion. Astroturf is a perversion of grassroots. Astroturf is when political, corporate or other special interests disguise themselves and publish blogs, start facebook and twitter accounts, publish ads, letters to the editor, or simply post comments online, to try to fool you into thinking an independent or grassroots movement is speaking. ~ Sharyl Attkisson, Investigative ReporterHow do you separate fact from fiction? Sharyl Attkisson finishes her talk with some insights on how to identify signs of propaganda and astroturfing  These methods are used to give people the impression that there is widespread support for an agenda, when, in reality, one may not exist. Astroturf tactics are also used to discredit or criticize those that disagree with certain agendas, using stereotypical names such as conspiracy theorist or quack. When in fact when someone dares to reveal the truth or questions the  official  story, it should spark a deeper curiosity and encourage further scrutiny of the information.This article (Journalist Reveals Tactics Brainwashing Industry Uses to Manipulate the Public) was originally created and published by Waking Times and is published here under a Creative Commons license with attribution to Vic Bishop and WakingTimes.com. It may be re-posted freely with proper attribution, author bio, and this copyright statement. READ MORE MSM PROPAGANDA NEWS AT: 21st Century Wire MSM Watch Files
